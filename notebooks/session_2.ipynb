# %%
import sys

sys.path.append("../src")

# %%
import geopandas as gpd
from geopandas.geodataframe import GeoDataFrame
import matplotlib.pyplot as plt

from config import Config
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
map_ : GeoDataFrame = gpd.read_file(Config.MEXICO_SHAPEFILE)

# %%
map_.crs.to_dict()
# Out:
# /Users/vic/Documents/repos/github/open_source/geostatistic-course/.venv/lib/python3.12/site-packages/pyproj/crs/crs.py:1295: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# {'proj': 'lcc',
#  'lat_0': 12,
#  'lon_0': -102,
#  'lat_1': 17.5,
#  'lat_2': 29.5,
#  'x_0': 2500000,
#  'y_0': 0,
#  'ellps': 'GRS80',
#  'units': 'm',
#  'no_defs': None,
#  'type': 'crs'}

# %%
map_title = "Proyección cartográfica de México\nDivisión política por entidad federativa"

plt.figure(figsize=(15, 11), dpi=500)
map_.plot(facecolor="white", edgecolor="black")
plt.title(map_title)
plt.xlabel("Longitud")
plt.ylabel("Latitud")
plt.grid(True, alpha=0.3)
plt.show()
